# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from plot_single_image_top_colors import plot
import os

filenumber = 13
cats = ['kitchen', 'bedroom', 'bathroom', 'living']
#cats = ['bedroom']
folder = u'C:\\Users\\Tiger\\Documents\\Python\\houzz\\'

plt.close('all')
for cat in cats:
    path = os.path.join(folder, '%s_pixels.pkl' % cat)
    df_pixels = pd.read_pickle(path)
    path = os.path.join(folder, '%s_top_colors.pkl' % cat)
    df_top_colors = pd.read_pickle(path)
    df_top_colors.index.name = 'filename'
    
    #plot(cat,filenumber,df_pixels,df_top_colors)

# %%
df_top_colors['color1'].value_counts()
# Out:
# silver            118
# darkgray           86
# gainsboro          45
# grey               45
# lightgray          42
# rosybrown          33
# black              25
# whitesmoke         20
# darkslategray      14
# dimgrey            14
# linen              13
# darkolivegreen     13
# tan                13
# lavender            5
# darkkhaki           3
# lightslategrey      2
# wheat               2
# antiquewhite        2
# burlywood           1
# saddlebrown         1
# darkseagreen        1
# sienna              1
# floralwhite         1
# Name: color1, dtype: int64

# %%
# Out:
#                     red  green   blue
# filenumber pixel
# 0          0      192.0  193.0  188.0
#            1      188.0  188.0  186.0
#            2      195.0  196.0  191.0
#            3      207.0  208.0  203.0
#            4      204.0  205.0  200.0
#            5      193.0  194.0  189.0
#            6      180.0  181.0  176.0
#            7      202.0  203.0  198.0
#            8      181.0  181.0  179.0
#            9      100.0   99.0   97.0
#            10     107.0  109.0  104.0
#            11      85.0   82.0   77.0
#            12      73.0   66.0   58.0
#            13     127.0  123.0  112.0
#            14     159.0  156.0  149.0
#            15     175.0  172.0  167.0
#            16     182.0  184.0  181.0
#            17     188.0  188.0  186.0
#            18     171.0  172.0  167.0
#            19     187.0  189.0  186.0
#            20     181.0  182.0  176.0
#            21     182.0  183.0  178.0
#            22     188.0  189.0  183.0
# ...
